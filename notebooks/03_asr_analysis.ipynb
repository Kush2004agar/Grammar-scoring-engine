# %% [markdown]
# ## Phase 3 — ASR Pipeline and Transcript Analysis
#
# This notebook inspects Whisper-generated transcripts and discusses how ASR behaviour affects grammar scoring.
#
# ### Goals
#
# - Load cached ASR transcripts for train and test.
# - Manually review a sample of low/medium/high score transcripts.
# - Identify common ASR error patterns (e.g., missing function words, tense substitutions).
# - Discuss implications for the validity and fairness of automated grammar scoring.
