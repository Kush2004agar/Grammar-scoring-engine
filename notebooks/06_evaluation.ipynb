# %% [markdown]
# ## Phase 7–8 — Evaluation, Error & Bias Analysis
#
# This notebook evaluates model predictions against human grammar scores and performs structured error/bias analysis.
#
# ### Goals
#
# - Compute Pearson/Spearman, MAE, and RMSE.
# - Analyse performance across low/medium/high score bands.
# - Plot predicted vs. actual scores and residuals.
# - Identify large-error cases and summarise qualitative insights about ASR and grammar failure modes.
