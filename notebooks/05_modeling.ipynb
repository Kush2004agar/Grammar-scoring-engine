# %% [markdown]
# ## Phase 6 — Baseline Modelling
#
# This notebook trains and interprets a **simple, transparent regression model** for grammar scoring.
#
# ### Goals
#
# - Train a baseline Ridge regression model on interpretable grammar features.
# - Use cross-validation with fixed random seeds.
# - Examine standardised coefficients as feature importance.
# - Document modelling decisions for assessment review.
