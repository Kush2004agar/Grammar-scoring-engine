# %% [markdown]
# ## Phase 5 — Grammar Feature Engineering
#
# This notebook documents the interpretable grammar features extracted from cleaned ASR transcripts.
#
# ### Goals
#
# - Describe each feature group (error counts, sentence completeness, syntactic complexity, POS patterns).
# - Show feature distributions and relationships with grammar scores.
# - Explain how each feature maps to human judgment of spoken grammar quality.
